# %% [markdown]
# #### Scraping Tweets to Study the Military & Race Relations During the 2020 #BlackLivesMatter Protests
#
# Brandon Kramer, Chase Dawson, Ed Gitre, Gizem Korkmaz

# %%
# load modules 
import requests
import os
import json
import pandas as pd 

# NOTE: need to set env variables (CONSUMER_KEY, CONSUMER_SECRET, BEARER_TOKEN)
# load the bearer_token and set twitter's archive as the url (academic research only) 
bearer_token = os.environ.get("BEARER_TOKEN")
search_url = "https://api.twitter.com/2/tweets/search/all"

# Optional params: start_time,end_time,since_id,until_id,max_results,next_token,
# expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields
#query_params = {'query': '(from:twitterdev -is:retweet) OR #twitterdev','tweet.fields': 'author_id'}
query_params = {'query': '#blacklivesmatter #fortbragg -is:retweet', 
                'start_time':'2020-05-01T01:00:00.01Z', 'end_time':'2020-09-01T01:00:00.01Z',
                'max_results': '100'
               }

# set functions to scrape our query for set time period 
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

def connect_to_endpoint(url, headers, params):
    response = requests.request("GET", search_url, headers=headers, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

def main():
    headers = create_headers(bearer_token)
    json_response = connect_to_endpoint(search_url, headers, query_params)
    print(json.dumps(json_response, indent=4, sort_keys=True))


if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "id": "1286419707805851649",
#             "text": "#MohacsiSteven works for the 849th Quarter Master Company @USArmy \n\n#FortBragg #NorthCarolina @FortBraggNC #StevenMohacsi \n#BlackLivesMatter #BLM https://t.co/V0rRBkxFLm"
#         },
#         {
#             "id": "1285047328999641089",
#             "text": "#CHINA #CCPVirus #COVID\u30fc19 \n#ChrisWallace #FakeNews \n#FortBragg  #PortlandProtest \n#BlackLivesMatter  #Antifa #WHO\n#TrustTheScience #Infiltration #CDC \n#Insurgents #DrFauci #DrBirx #DrRedstone\n#KanyeWest https://t.co/Qu71Vf5y5n"
#         },
#         {
#             "id": "1284958539014971394",
#             "text": "#CHINA #CCPVirus #COVID\u30fc19 \n#ChrisWallace #FakeNews \n#FortBragg  #PortlandProtest \n#BlackLivesMatter  #Antifa #WHO\n#TrustTheScience #Infiltration #CDC \n#Insurgents #DrFauci #DrBirx #DrRedstone\n#BillNye #BillNyeFakeScienceGuy https://t.co/VIvmJ76b1m"
#         },
#         {
#             "id": "1284958363957239809",
#             "text": "#CHINA #CCPVirus #COVID\u30fc19 \n#ChrisWallace #FakeNews \n#FortBragg  #PortlandProtest \n#BlackLivesMatter  #Antifa #WHO\n#TrustTheScience #Infiltration #CDC \n#Insurgents #DrFauci #DrBirx #DrRedstone\n#BillNye #BillNyeFakeScienceGuy https://t.co/T8vzIWNdtw"
#         },
#         {
#             "id": "1284957980191002625",
#             "text": "#CHINA #CCPVirus #COVID\u30fc19 \n#ChrisWallace #FakeNews \n#FortBragg  #PortlandProtest \n#BlackLivesMatter  #Antifa #WHO\n#TrustTheScience #Infiltration #CDC \n#Insurgents #DrFauci #DrBirx #DrRedstone\n#BillNye #BillNyeFakeScienceGuy https://t.co/Eg4iibQzfu"
#             "text": "#CHINA #CCPVirus #COVID\u30fc19 \n#ChrisWallace #FakeNews \n#FortBragg  #PortlandProtest \n#BlackLivesMatter  #Antifa #WHO\n#TrustTheScience #Infiltration #CDC \n#Insurgents #DrFauci #DrBirx #DrRedstone\n#MovesAndCountermoves https://t.co/cioB1TgT0a"
#         },
#         {
#             "id": "1284936628105105415",
#             "text": "#CHINA #CCPVirus #COVID\u30fc19 \n#ChrisWallace #FakeNews \n#FortBragg  #PortlandProtest \n#BlackLivesMatter  #Antifa #WHO\n#TrustTheScience #Infiltration #CDC \n#Insurgents #DrFauci #DrBirx #DrRedstone\n#MovesAndCountermoves https://t.co/SwDZ8SgOOL"
#         },
#         {
#             "id": "1284935564345643012",
#             "text": "#CHINA #CCPVirus #COVID\u30fc19 \n#ChrisWallace #FakeNews \n#FortBragg  #PortlandProtest \n#BlackLivesMatter  #Antifa #WHO\n#TrustTheScience #Infiltration #CDC \n#Insurgents #DrFauci #DrBirx #DrRedstone\n#MovesAndCountermoves https://t.co/iNB0FhtJ93"
#         },
#         {
#             "id": "1284933569278881792",
#             "text": "#CHINA #CCPVirus #COVID\u30fc19 \n#ChrisWallace #FakeNews \n#FortBragg  #PortlandProtest \n#BlackLivesMatter  #Antifa #WHO\n#TrustTheScience #Infiltration #CDC \n#Insurgents #DrFauci #DrBirx #DrRedstone\n#SwampRunsDeep https://t.co/rm4llswHJA"
#         },
#         {
#             "id": "1284917849929117696",
#             "text": "Come together as a nation! Mask Up America! #MAGA #GOP #TheResistance #MakeAmericaGreatAgain #BlackLivesMatter #VoteForOurLives @realDonaldTrump #VoteBiden2020 #FortBragg #portlandprotest https://t.co/rxAQYFeX2F"
#         },
#         {
#             "id": "1284915095559176195",
#             "text": "Sources say Florida\u2019 Guv DeSantis is slight over Georgia\u2019s Bryan Kemp for DUMBELL PIECE PRIZE. All hinges on who\u2019s all in for keeping Confederate traitors names on bases like Fort Bragg. #FortBragg #TrumpThreatensAmerica #TrumpIsNotWell #TrumpTraitor #BlackLivesMatter #Biden2020 https://t.co/WA6py3MBqD"
#         },
#         {
#             "id": "1281530684104998918",
#             "text": ".@POTUS 45* @realDonaldTrump \n\nWAKEY \nWAKEY \nDONNIE!!! \n\nTime for another #winning day! \n\nChairman of the Joint Chiefs of Staff @USArmy General #MarkMilley won't back you up #Trump because you are #wrong \n\n#FortHood \n#FortBragg \n#FortBenning \n#FortLee \n\n#BlackLivesMatter https://t.co/zvphSfFHcU"
#         },
#         {
#             "id": "1276495700398870530",
#             "text": "@DLTCGYDMM66 Resist Injustice.  Inequality. Police Brutality. Hate Crimes.  Resist the  Malicious Prosecution of Black Women Veterans in #FortBragg/FayettevilleNC. After the @ABC Extreme Makeover...\n#BarbaraSummeyMarshall \n#BlackLivesMatter https://t.co/CRMTDV6JrV"
#         },
#         {
#             "id": "1271526626220597248",
#             "text": "The ONLY solution to appease #NancyPelosi #Democrats &amp; to STOP their whining about SOUTHERN RACIST names, statues &amp; symbols is too erase ALL Confederate names &amp; references,,, SO,,, #FortBragg will now be named FortFagg, in recognition of Democrat Values. #Racism #BlackLivesMatter"
#         },
#         {
#             "id": "1271382539844956160",
#             "text": "No one should deface Civil War monuments, statues or change the name from Civil War soldier memories.  These were ALL Americans fighting, North and South alike.  The name #FortBragg and others should stay forever. #Trump2020 #BlackLivesMatter https://t.co/1jDiOgY2cj"
#         },
#         {
#             "id": "1271197821543215105",
#             "text": "USA #CIVILWAR2 ,,CNN &amp; #BlacklivesMatter have declared WAR on ALL Confederate American's in ALL Southern States. ALL Confederate names, symbols, pictures, monuments, books, sign's are ORDERED to be destroyed and/or RENAMED! ALL Confederate's are N----! hating RACIST'S #FortBragg"
#         },
#         {
#             "id": "1271186845112696833",
#             "text": "With apologies to Ewan McGregor.\nOther than that, I said what I said.\n\n#truestory #confederatestatues #theconfederacylost #traitors #enemycombatant #FortBragg #FortBenning #FortHood  #doublethink #blacklivesmatter #blm #starwars  #funnymemes \n#standintheater #tntpogbamtfbwy https://t.co/j493Mb0VCs"
#         },
#         {
#             "id": "1271097909778546688",
#             "text": "https://t.co/wfftpYkX85 #slate #ThursdayThoughts #military #ConfederateFlag #ConfederateMonuments #ConfederatePresident #DonaldTrump #DonaldTrump #racism #RacismInAmerica #Traitors #slavery #slavers #FortBragg #fort #army #Marines #RacistTrump #blacklivesmatter #folllowme"
#         },
#         {
#             "id": "1270798439564132362",
#             "text": "Should we rename the Joe Biden Welcome Center? \n\nHe supported segregationists\n\n#YouAintBlack #BidenHarris2020 #FortBragg #BLM #BlackLivesMatter #AllLivesMatter #KAG #KAGA2020 #MAGA @CNN @nytimes @FoxNews @ABC @nypost @nj1015 #Biden #JoeBiden #Biden2020 \n\nhttps://t.co/JoLP69Fgzh"
#         },
#         {
#             "id": "1267408351920562176",
#             "text": "@FeministaJones Disabled Black Women Veterans face police brutality in #FortBragg/FayettevilleNC...\n@ABC Extreme Makeover Jubilee House. \nUpheld by @TheDemocrats Gov/SoS/AG...Hostility and Intimidation. \n#BarbaraSummeyMarshall \n#BlackLivesMatter https://t.co/ryyhUhlvhD"
#         }
#     ],
#     "meta": {
#         "newest_id": "1286419707805851649",
#         "oldest_id": "1267408351920562176",
#         "result_count": 27
#     }
# }

# %%
json_response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a16cb387bda7> in <module>
# ----> 1 json_response
#
# NameError: name 'json_response' is not defined

# %% [raw]
# #### References
#
# [Twitter Sample Code (All)](https://github.com/twitterdev/Twitter-API-v2-sample-code)
#
# [Twitter Sample Code (Full Archive)](https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/master/Full-Archive-Search/full-archive-search.py)
#
# [Twitter Add Users to Organization Account](https://developer.twitter.com/ja/docs/basics/developer-portal/guides/team)
#
# [Twitter Building Queries](https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query)
#
# [Twitter Query Paramers](https://developer.twitter.com/en/docs/twitter-api/tweets/search/api-reference/get-tweets-search-all)
